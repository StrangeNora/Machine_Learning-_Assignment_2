# %% [markdown]
# # Machine Learning - Assignment 2

# %% [markdown]
# ### Part A:

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Spotify_Youtube.csv") 
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %% [markdown]
# #### We start by checking the data types of each column as well as looking for missing values and duplicates.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0    Artist  \
# count   20718.000000     20718
# unique           NaN      2079
# top              NaN  Gorillaz
# freq             NaN        10
# mean    10358.500000       NaN
# std      5980.915774       NaN
# min         0.000000       NaN
# 25%      5179.250000       NaN
# 50%     10358.500000       NaN
# 75%     15537.750000       NaN
# max     20717.000000       NaN
#
#                                               Url_spotify  \
# count                                               20718
# unique                                               2079
# top     https://open.spotify.com/artist/3AA28KZvwAUcZu...
# freq                                                   10
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# **Summary** There are some missing values in a few columns, such as Danceability, Views, Likes, and Comments. However, the number of missing rows is relatively small compared to the full dataset (less than 5% in most cases).
#
# For simplicity and to maintain data quality, we will drop the rows with missing values in these columns, as this will not significantly impact our analysis.

# %%
df = df.dropna()
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Artist, Url_spotify, Track, Album, Album_type, Uri, Danceability, Energy, Key, Loudness, Speechiness, Acousticness, Instrumentalness, Liveness, Valence, Tempo, Duration_ms, Url_youtube, Title, Channel, Views, Likes, Comments, Description, Licensed, official_video, Stream]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate Data found.

# %%
import matplotlib.pyplot as plt

mood_counts = df['Valence'].apply(lambda x: 'Happy' if x >= 0.5 else 'Sad').value_counts()

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(mood_counts, labels=mood_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Happy vs Sad Songs (Based on Valence)")
plt.show()

# %% [markdown]
# comment:

# %% [markdown]
# Album Type Distribution

# %%
# Group by Album and aggregate total Streams and Views
album_stats = df.groupby('Album')[['Stream', 'Views']].sum().sort_values(by='Stream', ascending=False).head(15)

# Plotting total Streams and Views per album (top 15 by stream)
plt.figure(figsize=(12, 6))
album_stats.plot(kind='bar', figsize=(12, 6), color={'Stream': 'chocolate', 'Views': 'darkorange'})
plt.title("Top 15 Albums by Stream and Views")
plt.ylabel("Count")
plt.xlabel("Album")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
popularity_df = df[(df[['Stream', 'Likes', 'Comments', 'Views']] > 0).all(axis=1)].copy()

popularity_df['Popularity'] = (
    popularity_df['Stream'].rank(pct=True) +
    popularity_df['Likes'].rank(pct=True) +
    popularity_df['Comments'].rank(pct=True) +
    popularity_df['Views'].rank(pct=True)
) / 4

# Replot the 2D density plot with no warning
plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=popularity_df,
    x='Valence',
    y='Energy',
    weights=popularity_df['Popularity'],
    fill=True,
    cmap='viridis',
    thresh=0.01,
    levels=100
)
plt.title("Valence vs Energy (Weighted by Popularity)")
plt.xlabel("Valence")
plt.ylabel("Energy")
plt.tight_layout()
plt.show()

# %% [markdown]
# this plot shows where the most popular songs are concentrated based on:
#
# - Valence (musical positivity)
#
# - Energy (intensity and activity)
#
# The brighter areas represent combinations that correlate with higher popularity, based on a normalized blend of streams, likes, comments, and views.

# %% [markdown]
#  Danceability vs Energy

# %%
df_copy = df.copy()
df_copy['Album_type'] = df_copy['Album_type'].str.lower().replace('compilation', 'album')


plt.figure(figsize=(7, 5))
sns.scatterplot(data=df_copy, x='Danceability', y='Energy', hue='Album_type', alpha=0.5)
plt.title("Danceability vs Energy by Album Type")
plt.xlabel("Danceability")
plt.ylabel("Energy")
plt.legend()
plt.show()

# %% [markdown]
# Observation:
# There's a moderate positive correlation between danceability and energy, regardless of album type.
# Singles tend to be more energetic and danceable, suggesting a style difference.

# %% [markdown]
# All Numerical Features

# %%
# plot for happy songs
sns.lmplot(data=happy_df, x='Valence', y='Danceability', scatter_kws={'alpha':0.5, 'color':'green'}, line_kws={'color':'red'}, height=5, aspect=2)
plt.title('Happy Songs: Valence vs Danceability')
plt.xlabel('Valence')
plt.ylabel('Danceability')
plt.show()

# plot for sad songs
sns.lmplot(data=sad_df, x='Valence', y='Danceability', scatter_kws={'alpha': 0.5, 'color':'green'}, line_kws={'color':'red'}, height=5, aspect=2)
plt.title('Sad Songs: Valence vs Danceability')
plt.xlabel('Valence')
plt.ylabel('Danceability')
plt.show()

# %% [markdown]
# ## Observation: Valence vs. Danceability for Happy and Sad Songs
#
#
# 1. Happy Songs:
#
# The scatter plot for happy songs shows a moderate positive trend:
# As valence increases (i.e., the song feels more positive), danceability also tends to increase.
#
# This suggests that songs classified as "happy" often combine cheerful emotional tone with more rhythmic, danceable beats — supporting the idea that happier songs are more upbeat and body-moving.
#
# 2. Sad Songs:
#
# The sad songs plot shows a weaker or almost flat trend, possibly with more scattered data.
#
# This indicates that valence doesn't strongly predict danceability for sad songs — some sad songs might be surprisingly danceable, while others are more mellow or slow.
#
# It supports the idea that sadness in music is expressed in more varied ways — not all sad songs are slow or undanceable.

# %%
grouped_df = df.groupby(['official_video', 'Licensed']).size().unstack(fill_value=0)
grouped_df
grouped_df.columns = ['licensed_false', 'licensed_true']
grouped_df
sizes = [grouped_df['licensed_false'].iloc[1], grouped_df['licensed_true'].iloc[1]]
labels = ['Not Licensed', 'Licensed']
explode = (0.05, 0.05)  
colors = ['tomato', 'grey']

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors = colors, startangle=140, explode=explode, shadow=True)
plt.title('License Status of Official Videos')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Observation: license status of official videos
#
# The majority of official music videos are licensed, but a notable portion are not. This binary feature (Licensed) may be valuable in predictive modeling tasks, as it could influence content success metrics like views or streams.

# %% [markdown]
# ### Part B:

# %%
df['Album_type_clean'] = df['Album_type'].str.lower().replace('compilation', 'album')

loudness_min = df['Loudness'].min()

loudness_max = df['Loudness'].max()

normalized_loudness = (df['Loudness'] - loudness_min) / (loudness_max - loudness_min)

def classify_pitch(key):
    if key in [0, 1, 2, 3]:  # C, C#, D, D#
        return 'low'
    elif key in [4, 5, 6, 7]:  # E, F, F#, G
        return 'medium'
    else:  # G#, A, A#, B
        return 'high'

df = df.assign(
    Album_Song_Count = df.groupby(['Album_type_clean', 'Album'])['Track'].transform('count'),
    Average_Artist_Song_Views = df.groupby('Artist')['Views'].transform('mean'),
    Song_Name_Length = df['Track'].astype(str).apply(lambda x: len(x.split())),
    Total_Album_Length = df.groupby(['Album_type_clean', 'Album'])['Duration_ms'].transform('sum'),
    Fitness_for_Clubs = (df['Danceability'] + df['Energy'] + df['Valence'] + normalized_loudness) / 4,
    Pitch = df['Key'].apply(classify_pitch),
    Popular_Site = df.apply(lambda x: 'youtube' if x['Views'] > x['Stream'] else 'spotify', axis=1),
    Is_Remix = df[['Title', 'Track', 'Description']].astype(str).apply(lambda x: 'remix' in ' '.join(x).lower(), axis=1),
    Streams_per_Minute = df['Stream'] / (df['Duration_ms'] / 60000),
    Likes_to_Views = df['Likes'] / df['Views']
)

df['Mood_Label'] = pd.cut(
    df['Energy'] * df['Danceability'],
    bins=[-float('inf'), 0.2, 0.4, 0.6, 0.8, float('inf')],
    labels=['Mellow', 'Chill', 'Groovy', 'Upbeat', 'Hype']
)

df.drop(columns='Album_type_clean', inplace=True)

# %% [markdown]
# Besides the required features, I created six custom ones to better capture the musical qualities, listener behavior, and engagement patterns for each song:
#
# - Pitch
# This groups the song’s Key into ‘low’, ‘medium’, or ‘high’ pitch ranges. Since pitch can shape a song’s mood and emotional feel, it might also relate to genre or what listeners prefer.
#
# - Popular_Site
# A simple yes/no feature that shows whether a song is more popular on YouTube or Spotify by comparing Views and Streams. This helps us understand where the audience is most active, which could guide platform-specific promotion.
#
# - Is_Remix
# This flags whether a song is likely a remix by checking if the word “remix” appears in its Title, Track, or Description. Remixes often behave differently in terms of audience and streaming trends compared to original songs.
#
# - Streams per Minute
# Calculated by dividing total streams by the song length in minutes, this feature shows how often a song gets played per minute. It’s a good way to spot songs with high replay value or viral popularity.
#
# - Likes_to_Views_Ratio
# This measures YouTube engagement by dividing Likes by Views. A high ratio means listeners really like the song, while a low ratio could mean people are less engaged or indifferent.
#
# - Mood_Label
# Based on how energetic and danceable a song is, this groups tracks into five moods: ‘Mellow’, ‘Chill’, ‘Groovy’, ‘Upbeat’, and ‘Hype’. It helps capture the overall vibe, which is great for mood-based recommendations or playlists.

# %%
import numpy as np

df['Comments'] = df['Comments'].fillna(0)
df['Likes'] = df['Likes'].fillna(0)
df['Views'] = df['Views'].fillna(0)

# %% [markdown]
# We imputed missing values in the Comments column with 0, assuming that missing values likely represent songs where comments weren’t available or disabled. This preserves all rows for modeling and prevents errors in algorithms that don’t support NaN values. It's a safe and logical default for this type of engagement metric.

# %%
df['Log_Views'] = np.log1p(df['Views'])
df['Log_Streams'] = np.log1p(df['Stream'])
df['Log_Likes'] = np.log1p(df['Likes'])

# %% [markdown]
# We used a log transformation (specifically log1p, which is safe for zero values) on the features Views, Likes, and Streams because these numbers can vary wildly — from very small to extremely large. Applying the log helps to:
#
# Smooth out big differences in scale
#
# Make the data more “normal” or balanced
#
# Tone down the effect of really extreme values
#
# This kind of adjustment often helps models work better, especially those that rely on distances or assume data is roughly normally distributed.

# %%
df.drop(columns=['Uri', 'Url_spotify', 'Url_youtube', 'Unnamed: 0'], inplace=True)

# %% [markdown]
# We removed features like URLs and long text fields (Uri, Url_spotify, Url_youtube, Description) because they don’t really help with making predictions. These kinds of data can add unnecessary noise or even cause the model to overfit. Plus, they’re tricky to use directly without extra processing like natural language techniques. By dropping them, we keep the dataset simpler and focus on the useful, structured information the model can learn from.

# %%
plt.figure(figsize=(12, 10))
corr_matrix = df.select_dtypes(include='number').corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %% [markdown]
# Observation:
# Strong positive correlations exist between Views, Likes, and Streams — which all reflect popularity.
# These features may be redundant and require dimensionality reduction or feature selection later.

# %% [markdown]
# Likes Vs views Ratio

# %%
df['likes_per_view'] = df['Likes'] / df['Views']

plt.figure(figsize=(10, 5))
plt.hist(df['likes_per_view'].dropna(), bins=50, color='orange')
plt.title("Distribution of Likes-to-Views Ratio (Audience Engagement)")
plt.xlabel("Likes per View")
plt.ylabel("Number of Songs")
plt.show()
